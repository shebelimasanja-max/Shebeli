# %%
from IPython.display import display, Markdown
display(Markdown("## EULER'S TOTIENT PROGRAM"))
display(Markdown("""### This program request input number (positive integer) from user
The program return all numbers from 1 to such number which are relative or coprime"""))
